# %% [markdown]
# <a href="https://colab.research.google.com/github/pedro-grohs/BootCamp-Data-Science--Grupo-3/blob/main/data/Imports.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
from datetime import datetime, timedelta
end_date = datetime.datetime.now()
start_date = end_date - timedelta(days= 7*365)

db = yf.download(["^OEX", "^BVSP"],
                 start= start_date, end= end_date)
